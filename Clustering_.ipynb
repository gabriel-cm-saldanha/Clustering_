# %% [markdown]
# <a href="https://colab.research.google.com/github/gabriel-cm-saldanha/Clustering_/blob/main/Clustering_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Libraries

# %%
# !pip install kmodes -q

# %%
# Data wrangling
import numpy as np
import pandas as pd

# Dataviz
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px
import plotly.graph_objects as go

from yellowbrick.cluster import KElbowVisualizer, SilhouetteVisualizer, InterclusterDistance, kelbow_visualizer, silhouette_visualizer

## -- Machine learning -- ##
from sklearn import datasets
from sklearn.mixture import GaussianMixture
from sklearn.cluster import KMeans, DBSCAN, MeanShift
from sklearn.cluster import k_means, dbscan, mean_shift, estimate_bandwidth
from sklearn.metrics import silhouette_score, davies_bouldin_score, calinski_harabasz_score
from sklearn.decomposition import PCA
from sklearn.preprocessing import scale

from sklearn.cluster import AgglomerativeClustering
from scipy.cluster.hierarchy import linkage, dendrogram, fcluster

from kmodes.kmodes import KModes            # clustering categorical data
from kmodes.kprototypes import KPrototypes  # clustering mixed data

# Didatic purposes
import string
from ipywidgets import interact

# %%
# https://matplotlib.org/stable/tutorials/introductory/customizing.html
sns.set_theme(
    context='talk',
    style='ticks',
    font_scale=.6,
    palette='tab10',
    rc={
        'figure.figsize': (12,6),
        'axes.grid': True,
        'grid.alpha': .2,
        'axes.titlesize': 'x-large',
        'axes.titleweight': 'bold',
        'axes.titlepad': 20,
    }
)

scatter_kwargs = dict(palette='viridis', alpha=0.8, linewidth=0)

# %% [markdown]
# ### Data

# %%
df_wines,_ = datasets.load_wine(as_frame=True, return_X_y=True)
df_wines
# Out:
#      alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols  \
# 0      14.23        1.71  2.43               15.6      127.0           2.80
# 1      13.20        1.78  2.14               11.2      100.0           2.65
# 2      13.16        2.36  2.67               18.6      101.0           2.80
# 3      14.37        1.95  2.50               16.8      113.0           3.85
# 4      13.24        2.59  2.87               21.0      118.0           2.80
# ..       ...         ...   ...                ...        ...            ...
# 173    13.71        5.65  2.45               20.5       95.0           1.68
# 174    13.40        3.91  2.48               23.0      102.0           1.80
# 175    13.27        4.28  2.26               20.0      120.0           1.59
# 176    13.17        2.59  2.37               20.0      120.0           1.65
# 177    14.13        4.10  2.74               24.5       96.0           2.05
#
#      flavanoids  nonflavanoid_phenols  proanthocyanins  color_intensity   hue  \
# 0          3.06                  0.28             2.29             5.64  1.04
# 1          2.76                  0.26             1.28             4.38  1.05
# 2          3.24                  0.30             2.81             5.68  1.03
# 3          3.49                  0.24             2.18             7.80  0.86
# 4          2.69                  0.39             1.82             4.32  1.04
# ..          ...                   ...              ...              ...   ...
# 173        0.61                  0.52             1.06             7.70  0.64
# 174        0.75                  0.43             1.41             7.30  0.70
# 175        0.69                  0.43             1.35            10.20  0.59
# 176        0.68                  0.53             1.46             9.30  0.60
# 177        0.76                  0.56             1.35             9.20  0.61
#
#      od280/od315_of_diluted_wines  proline
# 0                            3.92   1065.0
# 1                            3.40   1050.0
# 2                            3.17   1185.0
# 3                            3.45   1480.0
# 4                            2.93    735.0
# ..                            ...      ...
# 173                          1.74    740.0
# 174                          1.56    750.0
# 175                          1.56    835.0
# 176                          1.62    840.0
# 177                          1.60    560.0
#
# [178 rows x 13 columns]

# %% [markdown]
# ### Data Cleaning

# %%
df_wines.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 178 entries, 0 to 177
# Data columns (total 13 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   alcohol                       178 non-null    float64
#  1   malic_acid                    178 non-null    float64
#  2   ash                           178 non-null    float64
#  3   alcalinity_of_ash             178 non-null    float64
#  4   magnesium                     178 non-null    float64
#  5   total_phenols                 178 non-null    float64
#  6   flavanoids                    178 non-null    float64
#  7   nonflavanoid_phenols          178 non-null    float64
#  8   proanthocyanins               178 non-null    float64
#  9   color_intensity               178 non-null    float64
#  10  hue                           178 non-null    float64
#  11  od280/od315_of_diluted_wines  178 non-null    float64
#  12  proline                       178 non-null    float64
# dtypes: float64(13)
# memory usage: 18.2 KB

# %% [markdown]
# Há dados duplicados?

# %%
df_wines.duplicated().any()
# Out:
# False

# %% [markdown]
# Há dados faltantes?

# %%
df_wines.isna().sum().any()
# Out:
# False

# %% [markdown]
# Há outliers?

# %%
df_wines.apply(scale).plot.box()
plt.xticks(rotation=60, ha='right');

# %% [markdown]
# Identificando e reomvendo linhas com outliers (|Z-Score| > 3):

# %%
df_wines_scaled = df_wines.apply(scale)

# %%
df_wines_scaled.abs().gt(3).any(axis=1).sum()
# Out:
# 10

# %%
outlier_rows = df_wines_scaled.abs().gt(3).any(axis=1)
df_wines_scaled = df_wines_scaled[~outlier_rows]

# %% [markdown]
# ### Verificando melhor K

# %%
kelbow_visualizer(KMeans(n_init="auto"),df_wines_scaled, k=12);

# %% [markdown]
# ### Clusterizando

# %% [markdown]
# Criando e Treiando modelo

# %%
model = KMeans(5, random_state=0, n_init="auto").fit(df_wines_scaled)

# %% [markdown]
# salvando Centroides e Labels

# %%
centroids = model.cluster_centers_
labels = model.labels_

# %% [markdown]
# ### Interpretando Clusters

# %%
(
  pd.DataFrame(centroids, columns = df_wines_scaled.columns)
  .T.add_prefix("Grupo_")
  .plot.bar(subplots=True, figsize=(12,12), legend=False)
)
plt.xticks(rotation=60, ha='right')
plt.tight_layout()

# %%
centers = pd.DataFrame(centroids, columns=df_wines_scaled.columns)
centers
# Out:
#     alcohol  malic_acid       ash  alcalinity_of_ash  magnesium  \
# 0  0.948874   -0.284919  0.299388          -0.771847   0.451743
# 1 -0.511714   -0.530424 -0.605353          -0.424340  -0.045685
# 2 -0.766628   -0.733554 -1.275776          -0.423885  -0.604998
# 3  0.210916    1.082514  0.299344           0.639624  -0.061643
# 4 -1.017927   -0.214405  0.272033           0.748477  -0.604998
#
#    total_phenols  flavanoids  nonflavanoid_phenols  proanthocyanins  \
# 0       0.891644    0.968240             -0.603017         0.556018
# 1      -0.904041   -0.949384              1.105829        -1.060789
# 2       0.162056    0.202363             -0.585700         0.113041
# 3      -1.025672   -1.245098              0.671806        -0.805941
# 4      -0.166422    0.061912              0.244422         0.050440
#
#    color_intensity       hue  od280/od315_of_diluted_wines   proline
# 0         0.232061  0.444536                      0.781897  1.195810
# 1        -0.277198 -0.373300                     -1.167004 -0.429567
# 2        -0.748601  0.773490                      0.431946 -0.682071
# 3         0.983252 -1.187351                     -1.283530 -0.389978
# 4        -0.975430  0.245639                      0.337489 -0.834595

# %%
(
    df_wines[~outlier_rows].assign(cluster=labels)
    .groupby("cluster")
    .agg(['mean','min','median','max'])
)
# Out:
#            alcohol                      malic_acid                     \
#               mean    min median    max       mean   min median   max
# cluster
# 0        13.768772  12.85  13.76  14.83   2.018947  1.35  1.770  4.04
# 1        12.586364  11.84  12.60  13.34   1.745455  0.94  1.360  3.43
# 2        12.380000  11.62  12.31  13.67   1.519167  0.90  1.375  3.17
# 3        13.171364  12.20  13.17  14.16   3.542273  1.67  3.410  5.65
# 4        12.176562  11.41  12.08  13.86   2.097500  0.74  1.710  4.43
#
#               ash        ...    hue       od280/od315_of_diluted_wines        \
#              mean   min  ... median   max                         mean   min
# cluster                  ...
# 0        2.448421  2.04  ...  1.060  1.28                     3.165263  2.51
# 1        2.200909  1.98  ...  0.906  1.25                     1.785455  1.29
# 2        2.017500  1.70  ...  1.155  1.42                     2.917500  2.14
# 3        2.448409  2.15  ...  0.665  0.96                     1.702955  1.27
# 4        2.440937  2.00  ...  0.965  1.45                     2.850625  2.23
#
#                           proline
#         median   max         mean    min  median     max
# cluster
# 0        3.170  4.00  1122.403509  680.0  1095.0  1680.0
# 1        1.670  2.52   612.000000  372.0   640.0   870.0
# 2        2.960  3.57   532.708333  278.0   498.5  1020.0
# 3        1.685  2.47   624.431818  415.0   607.5   880.0
# 4        2.810  3.64   484.812500  315.0   469.0   680.0
#
# [5 rows x 52 columns]

# %%
(
    df_wines[~outlier_rows].assign(cluster=labels)
    .groupby("cluster")
    .mean()
    .T
    .style.background_gradient(cmap="YlOrRd", axis=1)
)
# Out:
# <style type="text/css">
# #T_54347_row0_col0, #T_54347_row1_col3, #T_54347_row2_col0, #T_54347_row2_col3, #T_54347_row3_col4, #T_54347_row4_col0, #T_54347_row5_col0, #T_54347_row6_col0, #T_54347_row7_col1, #T_54347_row8_col0, #T_54347_row9_col3, #T_54347_row10_col2, #T_54347_row11_col0, #T_54347_row12_col0 {
#   background-color: #800026;
#   color: #f1f1f1;
# }
# #T_54347_row0_col1 {
#   background-color: #fed774;
#   color: #000000;
# }
# #T_54347_row0_col2 {
#   background-color: #ffeda0;
#   color: #000000;
# }
# #T_54347_row0_col3 {
#   background-color: #fc4f2a;
#   color: #f1f1f1;
# }
# #T_54347_row0_col4, #T_54347_row1_col2, #T_54347_row2_col2, #T_54347_row3_col0, #T_54347_row4_col2, #T_54347_row4_col4, #T_54347_row5_col3, #T_54347_row6_col3, #T_54347_row7_col0, #T_54347_row8_col1, #T_54347_row9_col4, #T_54347_row10_col3, #T_54347_row11_col3, #T_54347_row12_col4 {
#   background-color: #ffffcc;
#   color: #000000;
# }
# #T_54347_row1_col0 {
#   background-color: #fed977;
#   color: #000000;
# }
# #T_54347_row1_col1 {
#   background-color: #ffefa5;
#   color: #000000;
# }
# #T_54347_row1_col4 {
#   background-color: #fece6a;
#   color: #000000;
# }
# #T_54347_row2_col1 {
#   background-color: #fea446;
#   color: #000000;
# }
# #T_54347_row2_col4 {
#   background-color: #880026;
#   color: #f1f1f1;
# }
# #T_54347_row3_col1, #T_54347_row3_col2 {
#   background-color: #fedd7e;
#   color: #000000;
# }
# #T_54347_row3_col3 {
#   background-color: #a20026;
#   color: #f1f1f1;
# }
# #T_54347_row4_col1 {
#   background-color: #fd7e38;
#   color: #f1f1f1;
# }
# #T_54347_row4_col3 {
#   background-color: #fd863a;
#   color: #f1f1f1;
# }
# #T_54347_row5_col1 {
#   background-color: #fff6b6;
#   color: #000000;
# }
# #T_54347_row5_col2 {
#   background-color: #fc512b;
#   color: #f1f1f1;
# }
# #T_54347_row5_col4 {
#   background-color: #fd9d43;
#   color: #000000;
# }
# #T_54347_row6_col1 {
#   background-color: #ffec9d;
#   color: #000000;
# }
# #T_54347_row6_col2 {
#   background-color: #f64227;
#   color: #f1f1f1;
# }
# #T_54347_row6_col4 {
#   background-color: #fc5f2f;
#   color: #f1f1f1;
# }
# #T_54347_row7_col2 {
#   background-color: #fffec9;
#   color: #000000;
# }
# #T_54347_row7_col3 {
#   background-color: #e41c1d;
#   color: #f1f1f1;
# }
# #T_54347_row7_col4 {
#   background-color: #fd8f3d;
#   color: #f1f1f1;
# }
# #T_54347_row8_col2 {
#   background-color: #e8241f;
#   color: #f1f1f1;
# }
# #T_54347_row8_col3 {
#   background-color: #ffe895;
#   color: #000000;
# }
# #T_54347_row8_col4 {
#   background-color: #f03523;
#   color: #f1f1f1;
# }
# #T_54347_row9_col0 {
#   background-color: #fc532b;
#   color: #f1f1f1;
# }
# #T_54347_row9_col1 {
#   background-color: #feb852;
#   color: #000000;
# }
# #T_54347_row9_col2 {
#   background-color: #ffefa4;
#   color: #000000;
# }
# #T_54347_row10_col0 {
#   background-color: #c90823;
#   color: #f1f1f1;
# }
# #T_54347_row10_col1 {
#   background-color: #fea647;
#   color: #000000;
# }
# #T_54347_row10_col4 {
#   background-color: #e6211e;
#   color: #f1f1f1;
# }
# #T_54347_row11_col1 {
#   background-color: #fff7b9;
#   color: #000000;
# }
# #T_54347_row11_col2 {
#   background-color: #ca0923;
#   color: #f1f1f1;
# }
# #T_54347_row11_col4 {
#   background-color: #d9131f;
#   color: #f1f1f1;
# }
# #T_54347_row12_col1 {
#   background-color: #fee187;
#   color: #000000;
# }
# #T_54347_row12_col2 {
#   background-color: #fff4b2;
#   color: #000000;
# }
# #T_54347_row12_col3 {
#   background-color: #fede80;
#   color: #000000;
# }
# </style>
# <table id="T_54347" class="dataframe">
#   <thead>
#     <tr>
#       <th class="index_name level0" >cluster</th>
#       <th id="T_54347_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_54347_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_54347_level0_col2" class="col_heading level0 col2" >2</th>
#       <th id="T_54347_level0_col3" class="col_heading level0 col3" >3</th>
#       <th id="T_54347_level0_col4" class="col_heading level0 col4" >4</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_54347_level0_row0" class="row_heading level0 row0" >alcohol</th>
#       <td id="T_54347_row0_col0" class="data row0 col0" >13.768772</td>
#       <td id="T_54347_row0_col1" class="data row0 col1" >12.586364</td>
#       <td id="T_54347_row0_col2" class="data row0 col2" >12.380000</td>
#       <td id="T_54347_row0_col3" class="data row0 col3" >13.171364</td>
#       <td id="T_54347_row0_col4" class="data row0 col4" >12.176562</td>
#     </tr>
#     <tr>
#       <th id="T_54347_level0_row1" class="row_heading level0 row1" >malic_acid</th>
#       <td id="T_54347_row1_col0" class="data row1 col0" >2.018947</td>
#       <td id="T_54347_row1_col1" class="data row1 col1" >1.745455</td>
#       <td id="T_54347_row1_col2" class="data row1 col2" >1.519167</td>
#       <td id="T_54347_row1_col3" class="data row1 col3" >3.542273</td>
#       <td id="T_54347_row1_col4" class="data row1 col4" >2.097500</td>
#     </tr>
#     <tr>
#       <th id="T_54347_level0_row2" class="row_heading level0 row2" >ash</th>
#       <td id="T_54347_row2_col0" class="data row2 col0" >2.448421</td>
#       <td id="T_54347_row2_col1" class="data row2 col1" >2.200909</td>
#       <td id="T_54347_row2_col2" class="data row2 col2" >2.017500</td>
#       <td id="T_54347_row2_col3" class="data row2 col3" >2.448409</td>
#       <td id="T_54347_row2_col4" class="data row2 col4" >2.440937</td>
#     </tr>
#     <tr>
#       <th id="T_54347_level0_row3" class="row_heading level0 row3" >alcalinity_of_ash</th>
#       <td id="T_54347_row3_col0" class="data row3 col0" >16.924561</td>
#       <td id="T_54347_row3_col1" class="data row3 col1" >18.081818</td>
#       <td id="T_54347_row3_col2" class="data row3 col2" >18.083333</td>
#       <td id="T_54347_row3_col3" class="data row3 col3" >21.625000</td>
#       <td id="T_54347_row3_col4" class="data row3 col4" >21.987500</td>
#     </tr>
#     <tr>
#       <th id="T_54347_level0_row4" class="row_heading level0 row4" >magnesium</th>
#       <td id="T_54347_row4_col0" class="data row4 col0" >106.175439</td>
#       <td id="T_54347_row4_col1" class="data row4 col1" >99.090909</td>
#       <td id="T_54347_row4_col2" class="data row4 col2" >91.125000</td>
#       <td id="T_54347_row4_col3" class="data row4 col3" >98.863636</td>
#       <td id="T_54347_row4_col4" class="data row4 col4" >91.125000</td>
#     </tr>
#     <tr>
#       <th id="T_54347_level0_row5" class="row_heading level0 row5" >total_phenols</th>
#       <td id="T_54347_row5_col0" class="data row5 col0" >2.851579</td>
#       <td id="T_54347_row5_col1" class="data row5 col1" >1.730909</td>
#       <td id="T_54347_row5_col2" class="data row5 col2" >2.396250</td>
#       <td id="T_54347_row5_col3" class="data row5 col3" >1.655000</td>
#       <td id="T_54347_row5_col4" class="data row5 col4" >2.191250</td>
#     </tr>
#     <tr>
#       <th id="T_54347_level0_row6" class="row_heading level0 row6" >flavanoids</th>
#       <td id="T_54347_row6_col0" class="data row6 col0" >2.993684</td>
#       <td id="T_54347_row6_col1" class="data row6 col1" >1.083636</td>
#       <td id="T_54347_row6_col2" class="data row6 col2" >2.230833</td>
#       <td id="T_54347_row6_col3" class="data row6 col3" >0.789091</td>
#       <td id="T_54347_row6_col4" class="data row6 col4" >2.090937</td>
#     </tr>
#     <tr>
#       <th id="T_54347_level0_row7" class="row_heading level0 row7" >nonflavanoid_phenols</th>
#       <td id="T_54347_row7_col0" class="data row7 col0" >0.287018</td>
#       <td id="T_54347_row7_col1" class="data row7 col1" >0.499091</td>
#       <td id="T_54347_row7_col2" class="data row7 col2" >0.289167</td>
#       <td id="T_54347_row7_col3" class="data row7 col3" >0.445227</td>
#       <td id="T_54347_row7_col4" class="data row7 col4" >0.392188</td>
#     </tr>
#     <tr>
#       <th id="T_54347_level0_row8" class="row_heading level0 row8" >proanthocyanins</th>
#       <td id="T_54347_row8_col0" class="data row8 col0" >1.908246</td>
#       <td id="T_54347_row8_col1" class="data row8 col1" >0.985455</td>
#       <td id="T_54347_row8_col2" class="data row8 col2" >1.655417</td>
#       <td id="T_54347_row8_col3" class="data row8 col3" >1.130909</td>
#       <td id="T_54347_row8_col4" class="data row8 col4" >1.619687</td>
#     </tr>
#     <tr>
#       <th id="T_54347_level0_row9" class="row_heading level0 row9" >color_int

# %%
silhouette_score(df_wines_scaled, labels)
# Out:
# 0.2226812880160987
